# %%
import yfinance as yf
import pandas as pd

ticker = "AAPL"
df = yf.download(ticker, start="2015-01-01", end="2025-01-01")
df.reset_index(inplace=True)
df.to_csv("../data/stock_data.csv", index=False)
df.head()
# Out:
# C:\Users\kmrnr\AppData\Local\Temp\ipykernel_17708\1062106617.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2015-01-01", end="2025-01-01")
# [*********************100%***********************]  1 of 1 completed
# Price        Date      Close       High        Low       Open     Volume
# Ticker                  AAPL       AAPL       AAPL       AAPL       AAPL
# 0      2015-01-02  24.237553  24.705322  23.798602  24.694237  212818400
# 1      2015-01-05  23.554739  24.086799  23.368519  24.006990  257142000
# 2      2015-01-06  23.556961  23.816340  23.195602  23.619034  263188400
# 3      2015-01-07  23.887281  23.987042  23.654504  23.765350  160423600
# 4      2015-01-08  24.805080  24.862721  24.097883  24.215381  237458000
