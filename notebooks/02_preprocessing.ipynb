# %%
import pandas as pd

df = pd.read_csv("../data/stock_data.csv")

df = df[['Date','Open','High','Low','Close','Volume']]
df['Date'] = pd.to_datetime(df['Date'])
df['Prev_Close'] = df['Close'].shift(1)
df = df.dropna().reset_index(drop=True)

df.head()
# Out:
#         Date                Open                High                 Low  \
# 0 2015-01-02  24.694236978633914  24.705322239577697  23.798602356597982
# 1 2015-01-05  24.006990190147395    24.0867993234754  23.368518814896508
# 2 2015-01-06  23.619034466383983  23.816339948630354  23.195602497746687
# 3 2015-01-07   23.76535030250549   23.98704200939966  23.654504449058404
# 4 2015-01-08  24.215381460812253  24.862720720656704  24.097883456887466
#
#                 Close     Volume          Prev_Close
# 0  24.237552642822266  212818400                AAPL
# 1  23.554738998413086  257142000  24.237552642822266
# 2  23.556961059570312  263188400  23.554738998413086
# 3   23.88728141784668  160423600  23.556961059570312
# 4   24.80508041381836  237458000   23.88728141784668

# %%
import pandas as pd

df = pd.read_csv("../data/stock_data.csv")
df['Date'] = pd.to_datetime(df['Date'])
df['Prev_Close'] = df['Close'].shift(1)
df = df.dropna().reset_index(drop=True)

df.to_csv("../data/processed_stock_data.csv", index=False)

df.head()
# Out:
#         Date               Close                High                 Low  \
# 0 2015-01-02  24.237552642822266  24.705322239577697  23.798602356597982
# 1 2015-01-05  23.554738998413086    24.0867993234754  23.368518814896508
# 2 2015-01-06  23.556961059570312  23.816339948630354  23.195602497746687
# 3 2015-01-07   23.88728141784668   23.98704200939966  23.654504449058404
# 4 2015-01-08   24.80508041381836  24.862720720656704  24.097883456887466
#
#                  Open     Volume          Prev_Close
# 0  24.694236978633914  212818400                AAPL
# 1  24.006990190147395  257142000  24.237552642822266
# 2  23.619034466383983  263188400  23.554738998413086
# 3   23.76535030250549  160423600  23.556961059570312
# 4  24.215381460812253  237458000   23.88728141784668

# %%
plt.figure(figsize=(10,5))
plt.plot(df['Date'], df['Close'])
plt.title("Stock Closing Price Trend")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df['Date'], df['Volume'])
plt.title("Trading Volume Trend")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/processed_stock_data.csv")

df['Date'] = pd.to_datetime(df['Date'])

cols = ['Open','High','Low','Close','Volume','Prev_Close']
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')

df = df.dropna().reset_index(drop=True)

df.head()
# Out:
#         Date      Close       High        Low       Open     Volume  \
# 0 2015-01-05  23.554739  24.086799  23.368519  24.006990  257142000
# 1 2015-01-06  23.556961  23.816340  23.195602  23.619034  263188400
# 2 2015-01-07  23.887281  23.987042  23.654504  23.765350  160423600
# 3 2015-01-08  24.805080  24.862721  24.097883  24.215381  237458000
# 4 2015-01-09  24.831688  25.106585  24.432642  24.978004  214798000
#
#    Prev_Close
# 0   24.237553
# 1   23.554739
# 2   23.556961
# 3   23.887281
# 4   24.805080

# %%
df['Daily_Return'] = df['Close'].pct_change()

plt.figure(figsize=(10,5))
plt.plot(df['Date'], df['Daily_Return'])
plt.title("Daily Returns")
plt.xlabel("Date")
plt.ylabel("Return")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df['Date'], df['Close'])
plt.title("Stock Closing Price Trend")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df['Date'], df['Volume'])
plt.title("Trading Volume Trend")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[['Open','High','Low','Close','Volume','Prev_Close']].corr(), annot=True)
plt.title("Feature Correlation Heatmap")
plt.show()
